# %%
import xarray as xr
import zarr
import matplotlib.pyplot as plt
import intake                                             #Intake-esm is a data cataloging utility built on top of intake, pandas, and xarray
import dask                                              #Dask is a library that supports parallel computing in python
# %matplotlib inline
# fsspec: Filesystem interfaces to work with remote filesystems
import fsspec
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\anaconda3\envs\climate_indices\lib\site-packages\numpy\core\__init__.py in <module>
#      15 try:
# ---> 16     from . import multiarray
#      17 except ImportError as exc:
#
# ImportError: DLL load failed: The specified module could not be found.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6548\1710378846.py in <module>
# ----> 1 import xarray as xr
#       2 import zarr
#       3 import matplotlib.pyplot as plt
#       4 import intake                                             #Intake-esm is a data cataloging utility built on top of intake, pandas, and xarray
# ...

# %% [markdown]
# <b> CNRM data </b>

# %%
#reading data of more gcm 

url= "https://cmip6.storage.googleapis.com/pangeo-cmip6.json"                        #.json file 
col_gs = intake.open_esm_datastore(url)
query = dict(experiment_id=['historical','ssp585'],                                  
             source_id= ['CNRM-CM6-1'],
             table_id='day',
             variable_id=['tasmax','tasmin','pr'],
            member_id = 'r1i1p1f2'
             #grid_label='gr'
            )

col_gs_subset1 = col_gs.search(require_all_on=['source_id'], **query)                  #arguement for required data  
col_gs_subset1.df
# Out:
# C:\Users\Anurag\.conda\envs\anurag\lib\site-packages\intake_esm\_search.py:80: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for _, group in grouped:
#    activity_id institution_id   source_id experiment_id member_id table_id  \
# 0         CMIP   CNRM-CERFACS  CNRM-CM6-1    historical  r1i1p1f2      day
# 1         CMIP   CNRM-CERFACS  CNRM-CM6-1    historical  r1i1p1f2      day
# 2         CMIP   CNRM-CERFACS  CNRM-CM6-1    historical  r1i1p1f2      day
# 3  ScenarioMIP   CNRM-CERFACS  CNRM-CM6-1        ssp585  r1i1p1f2      day
# 4  ScenarioMIP   CNRM-CERFACS  CNRM-CM6-1        ssp585  r1i1p1f2      day
# 5  ScenarioMIP   CNRM-CERFACS  CNRM-CM6-1        ssp585  r1i1p1f2      day
#
#   variable_id grid_label                                             zstore  \
# ...

# %%
# intake-esm provides functionality to directly loads data to a dictionary of xarray dataset

dset_dict = col_gs_subset1.to_dataset_dict(zarr_kwargs={'consolidated': True})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# C:\Users\Anurag\AppData\Local\Temp\ipykernel_10540\3180867510.py:3: DeprecationWarning: cdf_kwargs and zarr_kwargs are deprecated and will be removed in a future version. Please use xarray_open_kwargs instead.
#   dset_dict = col_gs_subset1.to_dataset_dict(zarr_kwargs={'consolidated': True})
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
# ...

# %%
list(dset_dict.keys())
# Out:
# ['ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1.ssp585.day.gr',
#  'CMIP.CNRM-CERFACS.CNRM-CM6-1.historical.day.gr']

# %%
url= "https://cmip6.storage.googleapis.com/pangeo-cmip6.json"                        #.json file 
col_gs2 = intake.open_esm_datastore(url)
query2 = dict(experiment_id=['ssp126'],                                  
             source_id= ['CNRM-CM6-1'],
             table_id='day',
             variable_id=['tasmax','tasmin','pr'],
            member_id = 'r1i1p1f2'
             #grid_label='gr'
            )

col_gs_subset2 = col_gs2.search(require_all_on=['source_id'], **query2)                  #arguement for required data  
col_gs_subset2.df
# Out:
# C:\Users\Anurag\.conda\envs\anurag\lib\site-packages\intake_esm\_search.py:80: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for _, group in grouped:
#    activity_id institution_id   source_id experiment_id member_id table_id  \
# 0  ScenarioMIP   CNRM-CERFACS  CNRM-CM6-1        ssp126  r1i1p1f2      day
# 1  ScenarioMIP   CNRM-CERFACS  CNRM-CM6-1        ssp126  r1i1p1f2      day
# 2  ScenarioMIP   CNRM-CERFACS  CNRM-CM6-1        ssp126  r1i1p1f2      day
#
#   variable_id grid_label                                             zstore  \
# 0      tasmin         gr  gs://cmip6/CMIP6/ScenarioMIP/CNRM-CERFACS/CNRM...
# 1      tasmax         gr  gs://cmip6/CMIP6/ScenarioMIP/CNRM-CERFACS/CNRM...
# 2          pr         gr  gs://cmip6/CMIP6/ScenarioMIP/CNRM-CERFACS/CNRM...
#
#    dcpp_init_year   version
# ...

# %%
# intake-esm provides functionality to directly loads data to a dictionary of xarray dataset

dset_dict2 = col_gs_subset2.to_dataset_dict(zarr_kwargs={'consolidated': True})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# C:\Users\Anurag\AppData\Local\Temp\ipykernel_10540\548007565.py:3: DeprecationWarning: cdf_kwargs and zarr_kwargs are deprecated and will be removed in a future version. Please use xarray_open_kwargs instead.
#   dset_dict2 = col_gs_subset2.to_dataset_dict(zarr_kwargs={'consolidated': True})
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
# ...

# %%
list(dset_dict2.keys())
# Out:
# ['ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1.ssp126.day.gr']

# %%
url= "https://cmip6.storage.googleapis.com/pangeo-cmip6.json"                        #.json file 
col_gs3 = intake.open_esm_datastore(url)
query3 = dict(experiment_id=['ssp245'],                                  
             source_id= ['CNRM-CM6-1'],
             table_id='day',
             variable_id=['tasmax','tasmin','pr'],
            member_id = 'r1i1p1f2'
             #grid_label='gr'
            )

col_gs_subset3 = col_gs3.search(require_all_on=['source_id'], **query3)                  #arguement for required data  
col_gs_subset3.df
# Out:
# C:\Users\Anurag\.conda\envs\anurag\lib\site-packages\intake_esm\_search.py:80: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for _, group in grouped:
#    activity_id institution_id   source_id experiment_id member_id table_id  \
# 0  ScenarioMIP   CNRM-CERFACS  CNRM-CM6-1        ssp245  r1i1p1f2      day
# 1  ScenarioMIP   CNRM-CERFACS  CNRM-CM6-1        ssp245  r1i1p1f2      day
# 2  ScenarioMIP   CNRM-CERFACS  CNRM-CM6-1        ssp245  r1i1p1f2      day
#
#   variable_id grid_label                                             zstore  \
# 0      tasmin         gr  gs://cmip6/CMIP6/ScenarioMIP/CNRM-CERFACS/CNRM...
# 1      tasmax         gr  gs://cmip6/CMIP6/ScenarioMIP/CNRM-CERFACS/CNRM...
# 2          pr         gr  gs://cmip6/CMIP6/ScenarioMIP/CNRM-CERFACS/CNRM...
#
#    dcpp_init_year   version
# ...

# %%
# intake-esm provides functionality to directly loads data to a dictionary of xarray dataset

dset_dict3 = col_gs_subset3.to_dataset_dict(zarr_kwargs={'consolidated': True})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# C:\Users\Anurag\AppData\Local\Temp\ipykernel_10540\98670558.py:3: DeprecationWarning: cdf_kwargs and zarr_kwargs are deprecated and will be removed in a future version. Please use xarray_open_kwargs instead.
#   dset_dict3 = col_gs_subset3.to_dataset_dict(zarr_kwargs={'consolidated': True})
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
# ...

# %%
list(dset_dict3.keys())
# Out:
# ['ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1.ssp245.day.gr']

# %%
url= "https://cmip6.storage.googleapis.com/pangeo-cmip6.json"                        #.json file 
col_gs4 = intake.open_esm_datastore(url)
query4 = dict(experiment_id=['ssp370'],                                  
             source_id= ['CNRM-CM6-1'],
             table_id='day',
             variable_id=['tasmax','tasmin','pr'],
            member_id = 'r1i1p1f2'
             #grid_label='gr'
            )

col_gs_subset4 = col_gs4.search(require_all_on=['source_id'], **query4)                  #arguement for required data  
col_gs_subset4.df
# Out:
# C:\Users\Anurag\.conda\envs\anurag\lib\site-packages\intake_esm\_search.py:80: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for _, group in grouped:
#    activity_id institution_id   source_id experiment_id member_id table_id  \
# 0  ScenarioMIP   CNRM-CERFACS  CNRM-CM6-1        ssp370  r1i1p1f2      day
# 1  ScenarioMIP   CNRM-CERFACS  CNRM-CM6-1        ssp370  r1i1p1f2      day
# 2  ScenarioMIP   CNRM-CERFACS  CNRM-CM6-1        ssp370  r1i1p1f2      day
#
#   variable_id grid_label                                             zstore  \
# 0          pr         gr  gs://cmip6/CMIP6/ScenarioMIP/CNRM-CERFACS/CNRM...
# 1      tasmax         gr  gs://cmip6/CMIP6/ScenarioMIP/CNRM-CERFACS/CNRM...
# 2      tasmin         gr  gs://cmip6/CMIP6/ScenarioMIP/CNRM-CERFACS/CNRM...
#
#    dcpp_init_year   version
# ...

# %%
# intake-esm provides functionality to directly loads data to a dictionary of xarray dataset

dset_dict4 = col_gs_subset4.to_dataset_dict(zarr_kwargs={'consolidated': True})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# C:\Users\Anurag\AppData\Local\Temp\ipykernel_10540\1545686649.py:3: DeprecationWarning: cdf_kwargs and zarr_kwargs are deprecated and will be removed in a future version. Please use xarray_open_kwargs instead.
#   dset_dict4 = col_gs_subset4.to_dataset_dict(zarr_kwargs={'consolidated': True})
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
# ...

# %%
list(dset_dict4.keys())
# Out:
# ['ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1.ssp370.day.gr']

# %%
# data collection                              # tasmax, tasmin, pr
historical=dset_dict['CMIP.CNRM-CERFACS.CNRM-CM6-1.historical.day.gr'].sel(time=slice("1980-01-01","2010-01-01")).sel(lat=slice(0,40),lon=slice(60,100)).drop('time_bounds').drop('dcpp_init_year').drop('member_id').drop('height')   
ssp126=dset_dict2['ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1.ssp126.day.gr'].sel(time=slice("1980-01-01","2010-01-01")).sel(lat=slice(0,40),lon=slice(60,100)).drop('time_bounds').drop('dcpp_init_year').drop('member_id').drop('height')
ssp245=dset_dict3['ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1.ssp245.day.gr'].sel(time=slice("1980-01-01","2010-01-01")).sel(lat=slice(0,40),lon=slice(60,100)).drop('time_bounds').drop('dcpp_init_year').drop('member_id').drop('height')
ssp370=dset_dict4['ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1.ssp370.day.gr'].sel(time=slice("1980-01-01","2010-01-01")).sel(lat=slice(0,40),lon=slice(60,100)).drop('time_bounds').drop('dcpp_init_year').drop('member_id').drop('height')
ssp585=dset_dict['ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1.ssp585.day.gr'].sel(time=slice("1980-01-01","2010-01-01")).sel(lat=slice(0,40),lon=slice(60,100)).drop('time_bounds').drop('dcpp_init_year').drop('member_id').drop('height')

# %%
historical
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 29, lon: 29, member_id: 1, dcpp_init_year: 1, time: 10959)
# Coordinates:
#   * lat      (lat) float64 0.7004 2.101 3.502 4.903 ... 35.72 37.12 38.52 39.92
#   * lon      (lon) float64 60.47 61.88 63.28 64.69 ... 95.62 97.03 98.44 99.84
#   * time     (time) datetime64[ns] 1980-01-01T12:00:00 ... 2010-01-01T12:00:00
# Dimensions without coordinates: member_id, dcpp_init_year
# Data variables:
#     pr       (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 515, 29, 29), meta=np.ndarray>
#     tasmax   (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 1191, 29, 29), meta=np.ndarray>
#     tasmin   (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 759, 29, 29), meta=np.ndarray>
# Attributes: (12/61)
#     CMIP6_CV_version:                 cv=6.2.3.0-7-g2019642
#     Conventions:                      CF-1.7 CMIP-6.2
# ...

# %%
# data collection                              # tasmax, tasmin, pr
historical=dset_dict['CMIP.CNRM-CERFACS.CNRM-CM6-1.historical.day.gr'].sel(time=slice("1980-01-01","2010-01-01")).sel(lat=slice(0,40),lon=slice(60,100))  
ssp126=dset_dict2['ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1.ssp126.day.gr'].sel(time=slice("2020-01-01","2050-01-01")).sel(lat=slice(0,40),lon=slice(60,100))
ssp245=dset_dict3['ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1.ssp245.day.gr'].sel(time=slice("2020-01-01","2050-01-01")).sel(lat=slice(0,40),lon=slice(60,100))
ssp370=dset_dict4['ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1.ssp370.day.gr'].sel(time=slice("2020-01-01","2050-01-01")).sel(lat=slice(0,40),lon=slice(60,100))
ssp585=dset_dict['ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1.ssp585.day.gr'].sel(time=slice("2020-01-01","2050-01-01")).sel(lat=slice(0,40),lon=slice(60,100))

# %%
# historical_df = historical.to_dataframe()
# ssp126_df = ssp126.to_dataframe()
# ssp245_df = ssp245.to_dataframe()
# ssp370_df = ssp370.to_dataframe()
# ssp585_df = ssp585.to_dataframe()

# %%
# historical_df.to_csv('G:/ANURAG/GCM/CNRM/historical_cnrm.csv')

# %%
# ssp126_df.to_csv('G:/ANURAG/GCM/CNRM/ssp126_cnrm.csv')
# ssp245_df.to_csv('G:/ANURAG/GCM/CNRM/ssp245_cnrm.csv')
# ssp370_df.to_csv('G:/ANURAG/GCM/CNRM/ssp370_cnrm.csv')
# ssp585_df.to_csv('G:/ANURAG/GCM/CNRM/ssp585_cnrm.csv')

# %%
# historical.to_netcdf('G:/ANURAG/GCM/CNRM/historical_cnrm.nc')     #run
# ssp126.to_netcdf('G:/ANURAG/GCM/CNRM/ssp126_cnrm.nc')
# ssp245.to_netcdf('G:/ANURAG/GCM/CNRM/ssp245_cnrm.nc')
# ssp370.to_netcdf('G:/ANURAG/GCM/CNRM/ssp370_cnrm.nc')
# ssp585.to_netcdf('G:/ANURAG/GCM/CNRM/ssp585_cnrm.nc')

# %%
# historical_df.to_xarray('G:/ANURAG/GCM/CNRM/historical_cnrm.nc')to_netcdf

# %%
# import pandas as pd
# t=pd.read_csv('G:/ANURAG/GCM/CNRM/historical_cnrm.csv')

# %%
# t

# %%
# y=t.drop('member_id', axis=1).drop('axis_nbounds', axis=1).drop('height', axis=1).drop('dcpp_init_year', axis=1)

# %%
# pr_cnrm=y['pr']*86400

# %% [markdown]
# <b> ACCESS data </b>

# %%
#reading data of more gcm 

url= "https://cmip6.storage.googleapis.com/pangeo-cmip6.json"                        #.json file 
col_gs5 = intake.open_esm_datastore(url)
query5 = dict(experiment_id=['historical','ssp126','ssp245','ssp370','ssp585'],                                  
             source_id= ['ACCESS-CM2'],
             table_id='day',
             variable_id=['tasmax','tasmin','pr'],
            member_id = 'r1i1p1f1'
             #grid_label='gr'
            )

col_gs_subset5 = col_gs5.search(require_all_on=['source_id'], **query5)                  #arguement for required data  
col_gs_subset5.df
# Out:
# C:\Users\Anurag\.conda\envs\anurag\lib\site-packages\intake_esm\_search.py:80: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for _, group in grouped:
#     activity_id institution_id   source_id experiment_id member_id table_id  \
# 0   ScenarioMIP   CSIRO-ARCCSS  ACCESS-CM2        ssp370  r1i1p1f1      day
# 1   ScenarioMIP   CSIRO-ARCCSS  ACCESS-CM2        ssp370  r1i1p1f1      day
# 2   ScenarioMIP   CSIRO-ARCCSS  ACCESS-CM2        ssp370  r1i1p1f1      day
# 3   ScenarioMIP   CSIRO-ARCCSS  ACCESS-CM2        ssp245  r1i1p1f1      day
# 4   ScenarioMIP   CSIRO-ARCCSS  ACCESS-CM2        ssp245  r1i1p1f1      day
# 5          CMIP   CSIRO-ARCCSS  ACCESS-CM2    historical  r1i1p1f1      day
# 6          CMIP   CSIRO-ARCCSS  ACCESS-CM2    historical  r1i1p1f1      day
# ...

# %%
# intake-esm provides functionality to directly loads data to a dictionary of xarray dataset

dset_dict5 = col_gs_subset5.to_dataset_dict(zarr_kwargs={'consolidated': True})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# C:\Users\Anurag\AppData\Local\Temp\ipykernel_10540\4105135455.py:3: DeprecationWarning: cdf_kwargs and zarr_kwargs are deprecated and will be removed in a future version. Please use xarray_open_kwargs instead.
#   dset_dict5 = col_gs_subset5.to_dataset_dict(zarr_kwargs={'consolidated': True})
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
# ...

# %%
list(dset_dict5.keys())
# Out:
# ['ScenarioMIP.CSIRO-ARCCSS.ACCESS-CM2.ssp245.day.gn',
#  'ScenarioMIP.CSIRO-ARCCSS.ACCESS-CM2.ssp370.day.gn',
#  'ScenarioMIP.CSIRO-ARCCSS.ACCESS-CM2.ssp126.day.gn',
#  'CMIP.CSIRO-ARCCSS.ACCESS-CM2.historical.day.gn',
#  'ScenarioMIP.CSIRO-ARCCSS.ACCESS-CM2.ssp585.day.gn']

# %%
# data collection                              # tasmax, tasmin, pr
historical_access=dset_dict5['CMIP.CSIRO-ARCCSS.ACCESS-CM2.historical.day.gn'].sel(time=slice("1980-01-01","2010-01-01")).sel(lat=slice(0,40),lon=slice(60,100))  
ssp126_access=dset_dict5[ 'ScenarioMIP.CSIRO-ARCCSS.ACCESS-CM2.ssp126.day.gn'].sel(time=slice("2020-01-01","2050-01-01")).sel(lat=slice(0,40),lon=slice(60,100))
ssp245_access=dset_dict5['ScenarioMIP.CSIRO-ARCCSS.ACCESS-CM2.ssp245.day.gn'].sel(time=slice("2020-01-01","2050-01-01")).sel(lat=slice(0,40),lon=slice(60,100))
ssp370_access=dset_dict5['ScenarioMIP.CSIRO-ARCCSS.ACCESS-CM2.ssp370.day.gn'].sel(time=slice("2020-01-01","2050-01-01")).sel(lat=slice(0,40),lon=slice(60,100))
ssp585_access=dset_dict5['ScenarioMIP.CSIRO-ARCCSS.ACCESS-CM2.ssp585.day.gn'].sel(time=slice("2020-01-01","2050-01-01")).sel(lat=slice(0,40),lon=slice(60,100))

# %%
# historical_access_df = historical_access.to_dataframe()
# ssp126_access_df = ssp126_access.to_dataframe()
# ssp245_access_df = ssp245_access.to_dataframe()
# ssp370_access_df = ssp370_access.to_dataframe()
# ssp585_access_df = ssp585_access.to_dataframe()

# %%
# historical_access_df.to_csv('G:/ANURAG/GCM/ACCESS/historical_access.csv')     
# ssp126_access_df.to_csv('G:/ANURAG/GCM/ACCESS/ssp126_access.csv')
# ssp245_access_df.to_csv('G:/ANURAG/GCM/ACCESS/ssp245_access.csv')
# ssp370_access_df.to_csv('G:/ANURAG/GCM/ACCESS/ssp370_access.csv')
# ssp585_access_df.to_csv('G:/ANURAG/GCM/ACCESS/ssp585_access.csv')

# %%
# historical_access.to_netcdf('G:/ANURAG/GCM/ACCESS/historical_access.nc')     #run
# ssp126_access.to_netcdf('G:/ANURAG/GCM/ACCESS/ssp126_access.nc')
# ssp245_access.to_netcdf('G:/ANURAG/GCM/ACCESS/ssp245_access.nc')
# ssp370_access.to_netcdf('G:/ANURAG/GCM/ACCESS/ssp370_access.nc')
# ssp585_access.to_netcdf('G:/ANURAG/GCM/ACCESS/ssp585_access.nc')

# %% [markdown]
# <b> CanESM data </b>

# %%
#reading data of more gcm 

url= "https://cmip6.storage.googleapis.com/pangeo-cmip6.json"                        #.json file 
col_gs6 = intake.open_esm_datastore(url)
query6 = dict(experiment_id=['historical','ssp126','ssp245','ssp370','ssp585'],                                  
             source_id= ['CanESM5'],
             table_id='day',
             variable_id=['tasmax','tasmin','pr'],
            member_id = 'r10i1p2f1'
             #grid_label='gr'
            )

col_gs_subset6 = col_gs6.search(require_all_on=['source_id'], **query6)                  #arguement for required data  
col_gs_subset6.df
# Out:
# C:\Users\Anurag\.conda\envs\anurag\lib\site-packages\intake_esm\_search.py:80: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for _, group in grouped:
#     activity_id institution_id source_id experiment_id  member_id table_id  \
# 0          CMIP          CCCma   CanESM5    historical  r10i1p2f1      day
# 1          CMIP          CCCma   CanESM5    historical  r10i1p2f1      day
# 2          CMIP          CCCma   CanESM5    historical  r10i1p2f1      day
# 3   ScenarioMIP          CCCma   CanESM5        ssp585  r10i1p2f1      day
# 4   ScenarioMIP          CCCma   CanESM5        ssp585  r10i1p2f1      day
# 5   ScenarioMIP          CCCma   CanESM5        ssp585  r10i1p2f1      day
# 6   ScenarioMIP          CCCma   CanESM5        ssp370  r10i1p2f1      day
# ...

# %%
# intake-esm provides functionality to directly loads data to a dictionary of xarray dataset

dset_dict6 = col_gs_subset6.to_dataset_dict(zarr_kwargs={'consolidated': True})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# C:\Users\Anurag\AppData\Local\Temp\ipykernel_10540\770638255.py:3: DeprecationWarning: cdf_kwargs and zarr_kwargs are deprecated and will be removed in a future version. Please use xarray_open_kwargs instead.
#   dset_dict6 = col_gs_subset6.to_dataset_dict(zarr_kwargs={'consolidated': True})
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
# ...

# %%
list(dset_dict6.keys())
# Out:
# ['ScenarioMIP.CCCma.CanESM5.ssp585.day.gn',
#  'ScenarioMIP.CCCma.CanESM5.ssp126.day.gn',
#  'ScenarioMIP.CCCma.CanESM5.ssp370.day.gn',
#  'ScenarioMIP.CCCma.CanESM5.ssp245.day.gn',
#  'CMIP.CCCma.CanESM5.historical.day.gn']

# %%
# data collection                              # tasmax, tasmin, pr
historical_canesm=dset_dict6[ 'CMIP.CCCma.CanESM5.historical.day.gn'].sel(time=slice("1980-01-01","2010-01-01")).sel(lat=slice(0,40),lon=slice(60,100))  
ssp126_canesm=dset_dict6['ScenarioMIP.CCCma.CanESM5.ssp126.day.gn'].sel(time=slice("2020-01-01","2050-01-01")).sel(lat=slice(0,40),lon=slice(60,100))
ssp245_canesm=dset_dict6['ScenarioMIP.CCCma.CanESM5.ssp245.day.gn'].sel(time=slice("2020-01-01","2050-01-01")).sel(lat=slice(0,40),lon=slice(60,100))
ssp370_canesm=dset_dict6['ScenarioMIP.CCCma.CanESM5.ssp370.day.gn'].sel(time=slice("2020-01-01","2050-01-01")).sel(lat=slice(0,40),lon=slice(60,100))
ssp585_canesm=dset_dict6['ScenarioMIP.CCCma.CanESM5.ssp585.day.gn'].sel(time=slice("2020-01-01","2050-01-01")).sel(lat=slice(0,40),lon=slice(60,100))

# %%
# historical_canesm_df = historical_canesm.to_dataframe()
# ssp126_canesm_df = ssp126_canesm.to_dataframe()
# ssp245_canesm_df = ssp245_canesm.to_dataframe()
# ssp370_canesm_df = ssp370_canesm.to_dataframe()
# ssp585_canesm_df = ssp585_canesm.to_dataframe()

# %%
# historical_canesm.to_netcdf('G:/ANURAG/GCM/CanESM/historical_CanESM.nc')        #run
# ssp126_canesm.to_netcdf('G:/ANURAG/GCM/CanESM/ssp126_canesm.nc')
# ssp245_canesm.to_netcdf('G:/ANURAG/GCM/CanESM/ssp245_canesm.nc')
# ssp370_canesm.to_netcdf('G:/ANURAG/GCM/CanESM/ssp370_canesm.nc')
# ssp585_canesm.to_netcdf('G:/ANURAG/GCM/CanESM/ssp585_canesm.nc')

# %%
# historical_canesm_df.to_csv('G:/ANURAG/GCM/CanESM/historical_CanESM.csv')
# ssp126_canesm_df.to_csv('G:/ANURAG/GCM/CanESM/ssp126_CanESM.csv')
# ssp245_canesm_df.to_csv('G:/ANURAG/GCM/CanESM/ssp245_CanESM.csv')
# ssp370_canesm_df.to_csv('G:/ANURAG/GCM/CanESM/ssp370_CanESM.csv')
# ssp585_canesm_df.to_csv('G:/ANURAG/GCM/CanESM/ssp585_CanESM.csv')

# %% [markdown]
# <b> MIROC6 data </b>

# %%
#reading data of more gcm 

url= "https://cmip6.storage.googleapis.com/pangeo-cmip6.json"                        #.json file 
col_gs7 = intake.open_esm_datastore(url)
query7 = dict(experiment_id=['historical',
                             # 'ssp126','ssp245','ssp370','ssp585'
                            ],                                  
             source_id= ['MIROC6'],
             table_id='day',
             variable_id=['tasmax','tasmin','pr'],
            member_id = 'r4i1p1f1'
             #grid_label='gr'
            )

col_gs_subset7 = col_gs7.search(require_all_on=['source_id'], **query7)                  #arguement for required data  
col_gs_subset7.df
# Out:
# C:\Users\Anurag\.conda\envs\anurag\lib\site-packages\intake_esm\_search.py:80: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for _, group in grouped:
#   activity_id institution_id source_id experiment_id member_id table_id  \
# 0        CMIP          MIROC    MIROC6    historical  r4i1p1f1      day
# 1        CMIP          MIROC    MIROC6    historical  r4i1p1f1      day
# 2        CMIP          MIROC    MIROC6    historical  r4i1p1f1      day
#
#   variable_id grid_label                                             zstore  \
# 0      tasmax         gn  gs://cmip6/CMIP6/CMIP/MIROC/MIROC6/historical/...
# 1      tasmin         gn  gs://cmip6/CMIP6/CMIP/MIROC/MIROC6/historical/...
# 2          pr         gn  gs://cmip6/CMIP6/CMIP/MIROC/MIROC6/historical/...
#
#    dcpp_init_year   version
# ...

# %%
col_gs_subset7.df.head(50)
# Out:
#   activity_id institution_id source_id experiment_id member_id table_id  \
# 0        CMIP          MIROC    MIROC6    historical  r4i1p1f1      day
# 1        CMIP          MIROC    MIROC6    historical  r4i1p1f1      day
# 2        CMIP          MIROC    MIROC6    historical  r4i1p1f1      day
#
#   variable_id grid_label                                             zstore  \
# 0      tasmax         gn  gs://cmip6/CMIP6/CMIP/MIROC/MIROC6/historical/...
# 1      tasmin         gn  gs://cmip6/CMIP6/CMIP/MIROC/MIROC6/historical/...
# 2          pr         gn  gs://cmip6/CMIP6/CMIP/MIROC/MIROC6/historical/...
#
#    dcpp_init_year   version
# 0             NaN  20191016
# 1             NaN  20191016
# 2             NaN  20191016

# %%
#reading data of more gcm 

url= "https://cmip6.storage.googleapis.com/pangeo-cmip6.json"                        #.json file 
col_gs8 = intake.open_esm_datastore(url)
query8 = dict(experiment_id=['historical',
                             # 'ssp126','ssp245','ssp370','ssp585'
                            ],                                  
             source_id= ['MIROC6'],
             table_id='day',
             variable_id=['tasmax','tasmin','pr'],
            member_id = 'r4i1p1f1'
             #grid_label='gr'
            )

col_gs_subset8 = col_gs8.search(require_all_on=['source_id'], **query8)                  #arguement for required data  
col_gs_subset8.df
# Out:
# C:\Users\Anurag\.conda\envs\anurag\lib\site-packages\intake_esm\_search.py:80: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for _, group in grouped:
#   activity_id institution_id source_id experiment_id member_id table_id  \
# 0        CMIP          MIROC    MIROC6    historical  r4i1p1f1      day
# 1        CMIP          MIROC    MIROC6    historical  r4i1p1f1      day
# 2        CMIP          MIROC    MIROC6    historical  r4i1p1f1      day
#
#   variable_id grid_label                                             zstore  \
# 0      tasmax         gn  gs://cmip6/CMIP6/CMIP/MIROC/MIROC6/historical/...
# 1      tasmin         gn  gs://cmip6/CMIP6/CMIP/MIROC/MIROC6/historical/...
# 2          pr         gn  gs://cmip6/CMIP6/CMIP/MIROC/MIROC6/historical/...
#
#    dcpp_init_year   version
# ...

# %%
#reading data of more gcm 

url= "https://cmip6.storage.googleapis.com/pangeo-cmip6.json"                        #.json file 
col_gs9 = intake.open_esm_datastore(url)
query9 = dict(experiment_id=[
                             'ssp126','ssp245','ssp370','ssp585'
                            ],                                  
             source_id= ['MIROC6'],
             table_id='day',
             variable_id=['tasmax','tasmin','pr'],
            member_id = 'r3i1p1f1'
             #grid_label='gr'
            )

col_gs_subset9 = col_gs9.search(require_all_on=['source_id'], **query9)                  #arguement for required data  
col_gs_subset9.df
# Out:
# C:\Users\Anurag\.conda\envs\anurag\lib\site-packages\intake_esm\_search.py:80: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for _, group in grouped:
#     activity_id institution_id source_id experiment_id member_id table_id  \
# 0   ScenarioMIP          MIROC    MIROC6        ssp585  r3i1p1f1      day
# 1   ScenarioMIP          MIROC    MIROC6        ssp585  r3i1p1f1      day
# 2   ScenarioMIP          MIROC    MIROC6        ssp585  r3i1p1f1      day
# 3   ScenarioMIP          MIROC    MIROC6        ssp126  r3i1p1f1      day
# 4   ScenarioMIP          MIROC    MIROC6        ssp126  r3i1p1f1      day
# 5   ScenarioMIP          MIROC    MIROC6        ssp245  r3i1p1f1      day
# 6   ScenarioMIP          MIROC    MIROC6        ssp370  r3i1p1f1      day
# ...

# %%
# intake-esm provides functionality to directly loads data to a dictionary of xarray dataset

dset_dict8 = col_gs_subset8.to_dataset_dict(zarr_kwargs={'consolidated': True})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# C:\Users\Anurag\AppData\Local\Temp\ipykernel_10540\3627965255.py:3: DeprecationWarning: cdf_kwargs and zarr_kwargs are deprecated and will be removed in a future version. Please use xarray_open_kwargs instead.
#   dset_dict8 = col_gs_subset8.to_dataset_dict(zarr_kwargs={'consolidated': True})
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
# ...

# %%
# intake-esm provides functionality to directly loads data to a dictionary of xarray dataset

dset_dict9 = col_gs_subset9.to_dataset_dict(zarr_kwargs={'consolidated': True})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# C:\Users\Anurag\AppData\Local\Temp\ipykernel_10540\810107399.py:3: DeprecationWarning: cdf_kwargs and zarr_kwargs are deprecated and will be removed in a future version. Please use xarray_open_kwargs instead.
#   dset_dict9 = col_gs_subset9.to_dataset_dict(zarr_kwargs={'consolidated': True})
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
# ...

# %%
list(dset_dict8.keys())
# Out:
# ['CMIP.MIROC.MIROC6.historical.day.gn']

# %%
list(dset_dict9.keys())
# Out:
# ['ScenarioMIP.MIROC.MIROC6.ssp245.day.gn',
#  'ScenarioMIP.MIROC.MIROC6.ssp370.day.gn',
#  'ScenarioMIP.MIROC.MIROC6.ssp126.day.gn',
#  'ScenarioMIP.MIROC.MIROC6.ssp585.day.gn']

# %%
# data collection                              # tasmax, tasmin, pr
historical_miroc6=dset_dict8['CMIP.MIROC.MIROC6.historical.day.gn'].sel(time=slice("1980-01-01","2010-01-01")).sel(lat=slice(0,40),lon=slice(60,100))  
ssp126_miroc6=dset_dict9['ScenarioMIP.MIROC.MIROC6.ssp126.day.gn'].sel(time=slice("2020-01-01","2050-01-01")).sel(lat=slice(0,40),lon=slice(60,100))
ssp245_miroc6=dset_dict9['ScenarioMIP.MIROC.MIROC6.ssp245.day.gn'].sel(time=slice("2020-01-01","2050-01-01")).sel(lat=slice(0,40),lon=slice(60,100))
ssp370_miroc6=dset_dict9['ScenarioMIP.MIROC.MIROC6.ssp370.day.gn'].sel(time=slice("2020-01-01","2050-01-01")).sel(lat=slice(0,40),lon=slice(60,100))
ssp585_miroc6=dset_dict9['ScenarioMIP.MIROC.MIROC6.ssp585.day.gn'].sel(time=slice("2020-01-01","2050-01-01")).sel(lat=slice(0,40),lon=slice(60,100))

# %%
# historical_miroc6_df = historical_miroc6.to_dataframe()
# ssp126_miroc6_df = ssp126_miroc6.to_dataframe()
# ssp245_miroc6_df = ssp245_miroc6.to_dataframe()
# ssp370_miroc6_df = ssp370_miroc6.to_dataframe()
# ssp585_miroc6_df = ssp585_miroc6.to_dataframe()

# %%
# historical_miroc6_df.to_csv('G:/ANURAG/GCM/MIROC6/historical_miroc6.csv')
# ssp126_miroc6_df.to_csv('G:/ANURAG/GCM/MIROC6/ssp126_miroc6.csv')
# ssp245_miroc6_df.to_csv('G:/ANURAG/GCM/MIROC6/ssp245_miroc6.csv')
# ssp370_miroc6_df.to_csv('G:/ANURAG/GCM/MIROC6/ssp370_miroc6.csv')
# ssp585_miroc6_df.to_csv('G:/ANURAG/GCM/MIROC6/ssp585_miroc6.csv')

# %%
# historical_miroc6_df

# %%
import netCDF4 as nc

# %%
# historical_miroc6.to_netcdf('G:/ANURAG/GCM/MIROC6/historical_miroc6_df.nc')

# %%
# ssp126_miroc6.to_netcdf('G:/ANURAG/GCM/MIROC6/ssp126_miroc6.nc')
# ssp245_miroc6.to_netcdf('G:/ANURAG/GCM/MIROC6/ssp245_miroc6.nc')
# ssp370_miroc6.to_netcdf('G:/ANURAG/GCM/MIROC6/ssp370_miroc6.nc')
# ssp585_miroc6.to_netcdf('G:/ANURAG/GCM/MIROC6/ssp585_miroc6.nc')         #run

# %%
#reading data of more gcm 

url= "https://cmip6.storage.googleapis.com/pangeo-cmip6.json"                        #.json file 
col_gs10 = intake.open_esm_datastore(url)
query10 = dict(experiment_id=['historical',
                             # 'ssp126',
                             #  'ssp245',
                             #  'ssp370',
                             #  'ssp585'
                            ],                                  
             source_id= ['CNRM-CM6-1'],
             table_id='day',
             variable_id=['hur'],
            member_id = 'r1i1p1f2'
             #grid_label='gr'
            )

col_gs_subset10 = col_gs10.search(require_all_on=['source_id'], **query10)                  #arguement for required data  
col_gs_subset10.df
# Out:
# C:\Users\Anurag\.conda\envs\anurag\lib\site-packages\intake_esm\_search.py:80: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for _, group in grouped:
#   activity_id institution_id   source_id experiment_id member_id table_id  \
# 0        CMIP   CNRM-CERFACS  CNRM-CM6-1    historical  r1i1p1f2      day
#
#   variable_id grid_label                                             zstore  \
# 0         hur         gr  gs://cmip6/CMIP6/CMIP/CNRM-CERFACS/CNRM-CM6-1/...
#
#    dcpp_init_year   version
# 0             NaN  20180917

# %%
# intake-esm provides functionality to directly loads data to a dictionary of xarray dataset

dset_dict10 = col_gs_subset10.to_dataset_dict(zarr_kwargs={'consolidated': True})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# C:\Users\Anurag\AppData\Local\Temp\ipykernel_10540\2636089266.py:3: DeprecationWarning: cdf_kwargs and zarr_kwargs are deprecated and will be removed in a future version. Please use xarray_open_kwargs instead.
#   dset_dict10 = col_gs_subset10.to_dataset_dict(zarr_kwargs={'consolidated': True})
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
# ...

# %%
list(dset_dict10.keys())
# Out:
# ['CMIP.CNRM-CERFACS.CNRM-CM6-1.historical.day.gr']

# %%
# data collection                              # tasmax, tasmin, pr
historical_cnrm_hur=dset_dict10['CMIP.CNRM-CERFACS.CNRM-CM6-1.historical.day.gr'].sel(time=slice("1980-01-01","2010-01-01")).sel(lat=slice(0,40),lon=slice(60,100))

# %%
# historical_cnrm_hur.to_netcdf('G:/ANURAG/GCM/CNRM/hist_hur_cnrm.nc')

# %%
#relative humidity data

# %%
#reading data of more gcm 

url= "https://cmip6.storage.googleapis.com/pangeo-cmip6.json"                        #.json file 
col_gs11 = intake.open_esm_datastore(url)
query11 = dict(experiment_id=['historical',
                             # 'ssp126',
                             #  'ssp245',
                             #  'ssp370',
                             #  'ssp585'
                            ],                                   
             source_id= ['ACCESS-CM2'],
             table_id='day',
             variable_id=['hur'],
            # member_id = 'r2i1p1f2'
             #grid_label='gr'
            )

col_gs_subset11 = col_gs11.search(require_all_on=['source_id'], **query11)                  #arguement for required data  
col_gs_subset11.df
# Out:
# C:\Users\Anurag\.conda\envs\anurag\lib\site-packages\intake_esm\_search.py:80: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for _, group in grouped:
#   activity_id institution_id   source_id experiment_id member_id table_id  \
# 0        CMIP   CSIRO-ARCCSS  ACCESS-CM2    historical  r1i1p1f1      day
#
#   variable_id grid_label                                             zstore  \
# 0         hur         gn  gs://cmip6/CMIP6/CMIP/CSIRO-ARCCSS/ACCESS-CM2/...
#
#    dcpp_init_year   version
# 0             NaN  20191108

# %%
# intake-esm provides functionality to directly loads data to a dictionary of xarray dataset

dset_dict11 = col_gs_subset11.to_dataset_dict(zarr_kwargs={'consolidated': True})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# C:\Users\Anurag\AppData\Local\Temp\ipykernel_10540\3566124051.py:3: DeprecationWarning: cdf_kwargs and zarr_kwargs are deprecated and will be removed in a future version. Please use xarray_open_kwargs instead.
#   dset_dict11 = col_gs_subset11.to_dataset_dict(zarr_kwargs={'consolidated': True})
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
# ...

# %%
list(dset_dict11.keys())
# Out:
# ['CMIP.CSIRO-ARCCSS.ACCESS-CM2.historical.day.gn']

# %%
# data collection                              # tasmax, tasmin, pr
historical_access_hur=dset_dict11['CMIP.CSIRO-ARCCSS.ACCESS-CM2.historical.day.gn'].sel(time=slice("1980-01-01","2010-01-01")).sel(lat=slice(0,40),lon=slice(60,100))

# %%
# historical_access_hur.to_netcdf('G:/ANURAG/GCM/ACCESS/hist_hur_access.nc')

# %%
#reading data of more gcm 

url= "https://cmip6.storage.googleapis.com/pangeo-cmip6.json"                        #.json file 
col_gs12 = intake.open_esm_datastore(url)
query12 = dict(experiment_id=['ssp126',
                             # ,
                             #  'ssp245',
                             #  'ssp370',
                             #  'ssp585'
                            ],                                   
             source_id= ['CanESM5'],
             # table_id='day',
             variable_id=['hur'],
            # member_id = 'r2i1p1f2'
             #grid_label='gr'
            )

col_gs_subset12 = col_gs12.search(require_all_on=['source_id'], **query12)                  #arguement for required data  
col_gs_subset12.df
# Out:
# C:\Users\Anurag\.conda\envs\anurag\lib\site-packages\intake_esm\_search.py:80: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for _, group in grouped:
#     activity_id institution_id source_id experiment_id  member_id table_id  \
# 0   ScenarioMIP          CCCma   CanESM5        ssp126   r9i1p2f1     Amon
# 1   ScenarioMIP          CCCma   CanESM5        ssp126   r7i1p1f1     Amon
# 2   ScenarioMIP          CCCma   CanESM5        ssp126   r6i1p2f1     Amon
# 3   ScenarioMIP          CCCma   CanESM5        ssp126   r9i1p1f1     Amon
# 4   ScenarioMIP          CCCma   CanESM5        ssp126   r3i1p1f1     Amon
# 5   ScenarioMIP          CCCma   CanESM5        ssp126  r21i1p1f1     Amon
# 6   ScenarioMIP          CCCma   CanESM5        ssp126  r20i1p2f1     Amon
# ...
